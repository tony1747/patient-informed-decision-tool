# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import graphviz

# %load_ext autoreload
# %autoreload 2

# %%
import file_manipulation as fm
import visualization as vis

# %%
test_cycles_1= np.array([
    [1, 0.5, 1, 2],
    [1, 0.3, 5, 9],
    [2, 0.9, 2, 20],
    [2, 0.9, 10, 20],
    [3, 0.8, 30, 40],
    [4, 0.8, 70, 80],
    ], dtype=float)

# %%
cyc_df = fm.cycles_to_df(test_cycles_1)
report = fm.cycles_df_to_report(cyc_df)
sch_df = fm.report_to_df(report)
graph = vis.create_graph(sch_df)
graph
